# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/sambuddharay/FinalYearProject/main/datasets/england-premier-league-players-2018-to-2019-stats-formatted.csv'
df = pd.read_csv(url)

# %%
df.shape
# Out:
# (570, 47)

# %%
df.head()
# Out:
#          full_name  age   birthday birthday_GMT          league     season  \
# 0  Aaron Cresswell   32  629712000   15-12-1989  Premier League  2018/2019
# 1     Aaron Lennon   35  545554800   16-04-1987  Premier League  2018/2019
# 2       Aaron Mooy   32  653382000   15-09-1990  Premier League  2018/2019
# 3     Aaron Ramsey   31  662198400   26-12-1990  Premier League  2018/2019
# 4       Aaron Rowe   22  968310000   07-09-2000  Premier League  2018/2019
#
#      position       Current Club  minutes_played_overall  minutes_played_home  \
# 0    Defender    West Ham United                    1589                  888
# 1  Midfielder            Burnley                    1217                  487
# 2  Midfielder  Huddersfield Town                    2327                 1190
# 3  Midfielder            Arsenal                    1327                  689
# 4     Forward  Huddersfield Town                      69                   14
#
# ...

# %%
column_names = list(df.columns.values)

# %%
column_names
# Out:
# ['full_name',
#  'age',
#  'birthday',
#  'birthday_GMT',
#  'league',
#  'season',
#  'position',
#  'Current Club',
#  'minutes_played_overall',
#  'minutes_played_home',
#  'minutes_played_away',
#  'nationality',
#  'appearances_overall',
#  'appearances_home',
#  'appearances_away',
#  'goals_overall',
#  'goals_home',
#  'goals_away',
#  'assists_overall',
#  'assists_home',
#  'assists_away',
#  'penalty_goals',
#  'penalty_misses',
#  'clean_sheets_overall',
#  'clean_sheets_home',
#  'clean_sheets_away',
#  'conceded_overall',
#  'conceded_home',
#  'conceded_away',
#  'yellow_cards_overall',
#  'red_cards_overall',
#  'goals_involved_per_90_overall',
#  'assists_per_90_overall',
#  'goals_per_90_overall',
#  'goals_per_90_home',
#  'goals_per_90_away',
#  'min_per_goal_overall',
#  'conceded_per_90_overall',
#  'min_per_conceded_overall',
#  'min_per_match',
#  'min_per_card_overall',
#  'min_per_assist_overall',
#  'cards_per_90_overall',
# ...

# %%
data = df.drop(['birthday','birthday_GMT','league','season'], axis=1)

# %%
data['position'].unique()
# Out:
# array(['Defender', 'Midfielder', 'Forward', 'Goalkeeper'], dtype=object)

# %%
defenders = data.loc[df['position']=='Defender']

# %%
defenders.head()
# Out:
#           full_name  age  position     Current Club  minutes_played_overall  \
# 0   Aaron Cresswell   32  Defender  West Ham United                    1589
# 11      Adam Masina   28  Defender          Watford                    1003
# 12       Adam Smith   31  Defender  AFC Bournemouth                    2073
# 17  Adrian Mariappa   36  Defender          Watford                    1921
# 20   Alberto Moreno   30  Defender        Liverpool                     155
#
#     minutes_played_home  minutes_played_away nationality  appearances_overall  \
# 0                   888                  701     England                   20
# 11                  463                  540       Italy                   14
# 12                 1051                 1022     England                   25
# 17                  841                 1080     Jamaica                   26
# 20                   90                   65       Spain                    2
#
# ...

# %%
defenders.drop(['rank_in_league_top_attackers','rank_in_league_top_midfielders','rank_in_league_top_defenders','rank_in_club_top_scorer'], axis=1)
# Out:
#                   full_name  age  position             Current Club  \
# 0           Aaron Cresswell   32  Defender          West Ham United
# 11              Adam Masina   28  Defender                  Watford
# 12               Adam Smith   31  Defender          AFC Bournemouth
# 17          Adrian Mariappa   36  Defender                  Watford
# 20           Alberto Moreno   30  Defender                Liverpool
# ..                      ...  ...       ...                      ...
# 559              Willy Boly   31  Defender  Wolverhampton Wanderers
# 562              Yan Valery   23  Defender              Southampton
# 563              Yerry Mina   28  Defender                  Everton
# 567        Zechariah Medley   22  Defender                  Arsenal
# 568  Zeze  Steven Sessegnon   22  Defender                   Fulham
#
#      minutes_played_overall  minutes_played_home  minutes_played_away  \
# 0                      1589                  888                  701
# ...

# %%
midfielders = data.loc[df['position']=='Midfielder']

# %%
midfielders.drop(['rank_in_league_top_attackers','rank_in_league_top_midfielders','rank_in_league_top_defenders','rank_in_club_top_scorer'], axis=1)
# Out:
#              full_name  age    position            Current Club  \
# 1         Aaron Lennon   35  Midfielder                 Burnley
# 2           Aaron Mooy   32  Midfielder       Huddersfield Town
# 3         Aaron Ramsey   31  Midfielder                 Arsenal
# 5    Aaron Wan-Bissaka   24  Midfielder          Crystal Palace
# 6    Abdelhamid Sabiri   25  Midfielder       Huddersfield Town
# ..                 ...  ...         ...                     ...
# 555      Wilfried Zaha   29  Midfielder          Crystal Palace
# 556        Will Hughes   27  Midfielder                 Watford
# 561    Xherdan Shaqiri   31  Midfielder               Liverpool
# 565    Youri Tielemans   25  Midfielder          Leicester City
# 566      Yves Bissouma   26  Midfielder  Brighton & Hove Albion
#
#      minutes_played_overall  minutes_played_home  minutes_played_away  \
# 1                      1217                  487                  730
# ...

# %%
forwards = data.loc[df['position']=='Forward']

# %%
forwards.drop(['rank_in_league_top_attackers','rank_in_league_top_midfielders','rank_in_league_top_defenders','rank_in_club_top_scorer'], axis=1)
# Out:
#                        full_name  age position            Current Club  \
# 4                     Aaron Rowe   22  Forward       Huddersfield Town
# 8               Aboubakar Kamara   27  Forward                  Fulham
# 9    Adalberto Peñaranda Maestre   25  Forward                 Watford
# 13                Adama Diakhaby   26  Forward       Huddersfield Town
# 15               Ademola Lookman   25  Forward                 Everton
# ..                           ...  ...      ...                     ...
# 537                  Troy Deeney   34  Forward                 Watford
# 547              Viktor Gyökeres   24  Forward  Brighton & Hove Albion
# 548              Vincent Janssen   28  Forward       Tottenham Hotspur
# 558                      Willian   34  Forward                 Chelsea
# 564               Yoshinori Muto   30  Forward        Newcastle United
#
#      minutes_played_overall  minutes_played_home  minutes_played_away  \
# ...

# %%
goalkeepers = data.loc[df['position']=='Goalkeeper']

# %%
goalkeepers.drop(['rank_in_league_top_attackers','rank_in_league_top_midfielders','rank_in_league_top_defenders','rank_in_club_top_scorer'], axis=1)
# Out:
#                           full_name  age    position             Current Club  \
# 16                           Adrián   35  Goalkeeper          West Ham United
# 23                    Alex McCarthy   32  Goalkeeper              Southampton
# 26                    Alex Smithies   32  Goalkeeper             Cardiff City
# 33                   Alfie Whiteman   24  Goalkeeper        Tottenham Hotspur
# 36                   Alisson Becker   30  Goalkeeper                Liverpool
# 52                       Angus Gunn   26  Goalkeeper              Southampton
# 59                   Arijanet Muric   23  Goalkeeper          Manchester City
# 62                      Artur Boruc   42  Goalkeeper          AFC Bournemouth
# 66                    Asmir Begović   35  Goalkeeper          AFC Bournemouth
# 72                       Ben Foster   39  Goalkeeper                  Watford
# 74                        Ben Hamer   34  Goalkeeper        Huddersfield Town
# ...
